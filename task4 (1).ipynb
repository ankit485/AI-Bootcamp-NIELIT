# %%
import cv2 as cv
# Import the alternative imshow function for Colab
from google.colab.patches import cv2_imshow

img = cv.imread("/download.webp")
# Use cv2_imshow instead of cv2.imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=269x155>
